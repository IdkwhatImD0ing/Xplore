# %%
pip install urllib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\python3.11\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import urllib.parse, urllib.request, os, json
from dotenv import load_dotenv
load_dotenv()

def make_yelp_url(address, term = "attractions", radius = 20000, sort_by = "best_match", limit = 15):
    return "https://api.yelp.com/v3/businesses/search?" + urllib.parse.urlencode([("location", address), ("term", term), ("radius", radius), ("sort_by", sort_by), ("limit", limit)])

def get_yelp_header():
    return {
    "accept": "application/json",
    "Authorization": "Bearer " + os.getenv("YELP_API_KEY")
    }

def make_yelp_request(location):
    request = urllib.request.Request(make_yelp_url(location), headers = get_yelp_header())
    response = urllib.request.urlopen(request)
    if response.getcode() == 200:
        return json.loads(response.read().decode(encoding = 'utf-8'))

# %%
make_yelp_request("American High School, Fremont")
# Out:
# https://api.yelp.com/v3/businesses/search?location=American+High+School%2C+Fremont&term=attractions&radius=20000&sort_by=best_match&limit=15
# {'businesses': [{'id': 'AvLZeeScs86iAezBo1Rliw',
#    'alias': 'hayward-japanese-gardens-hayward-area-rec-and-park-district-hayward',
#    'name': 'Hayward Japanese Gardens - Hayward Area Rec. & Park District',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WgNTJ4Hpj5ISNCdbj4xkRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hayward-japanese-gardens-hayward-area-rec-and-park-district-hayward?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 372,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.6803391, 'longitude': -122.0801445},
#    'transactions': [],
#    'location': {'address1': '22373 N 3rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hayward',
#     'zip_code': '94546',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['22373 N 3rd St', 'Hayward, CA 94546']},
#    'phone': '+15108816700',
#    'display_phone': '(510) 881-6700',
#    'distance': 13956.1007315161},
#   {'id': 'R04SRWcTv5cAPodNLv5AOQ',
#    'alias': 'game-kastle-fremont',
#    'name': 'Game Kastle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1brZ5N05MNoeuq-5oA3DOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/game-kastle-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 74,
#    'categories': [{'alias': 'toys', 'title': 'Toy Stores'},
#     {'alias': 'hobbyshops', 'title': 'Hobby Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.532718, 'longitude': -121.958113},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3911 Washington Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94538',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3911 Washington Blvd', 'Fremont, CA 94538']},
#    'phone': '+15106514263',
#    'display_phone': '(510) 651-4263',
#    'distance': 6295.976048075134},
#   {'id': 'E3eneO1Iby3NUS--VGG9Sw',
#    'alias': 'quarry-lakes-fremont',
#    'name': 'Quarry Lakes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GPLVJjFkb4JrHyJ1NlmD3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quarry-lakes-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 230,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'fishing', 'title': 'Fishing'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.5772468, 'longitude': -122.0084046},
#    'transactions': [],
#    'location': {'address1': '2100 Isherwood Way',
#     'address2': None,
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94536',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2100 Isherwood Way', 'Fremont, CA 94536']},
#    'phone': '+18883272757',
#    'display_phone': '(888) 327-2757',
#    'distance': 1712.6025767055817},
#   {'id': '3pdxDH-EMmdmcjJo1rfsXw',
#    'alias': 'ardenwood-historic-farm-fremont',
#    'name': 'Ardenwood Historic Farm',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_EYvlTc1DJF5w8HSGSgzLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ardenwood-historic-farm-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 301,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.5564805424492,
#     'longitude': -122.050849447299},
#    'transactions': [],
#    'location': {'address1': '34600 Ardenwood Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94555',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['34600 Ardenwood Blvd', 'Fremont, CA 94555']},
#    'phone': '+18883272757',
#    'display_phone': '(888) 327-2757',
#    'distance': 3175.6076905400587},
#   {'id': 'fybjhKw4gSAoFWDybd_Pmg',
#    'alias': 'central-park-and-lake-elizabeth-fremont',
#    'name': 'Central Park and Lake Elizabeth',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sAZ0CVgBulk9Sn6HZU3eSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/central-park-and-lake-elizabeth-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 538,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'lakes', 'title': 'Lakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.547773, 'longitude': -121.96544},
#    'transactions': [],
#    'location': {'address1': '40000 Paseo Padre Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94538',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['40000 Paseo Padre Pkwy', 'Fremont, CA 94538']},
#    'phone': '+15107905541',
#    'display_phone': '(510) 790-5541',
#    'distance': 4907.7537889069745},
#   {'id': 'Xfx18fOrtkId8Qqpy2-Orw',
#    'alias': 'aqua-adventure-water-park-fremont-2',
#    'name': 'Aqua Adventure Water Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JG05_m27HxhE48qxiH01WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqua-adventure-water-park-fremont-2?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 244,
#    'categories': [{'alias': 'waterparks', 'title': 'Water Parks'},
#     {'alias': 'swimminglessons', 'title': 'Swimming Lessons/Schools'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 37.54313, 'longitude': -121.960618},
#    'transactions': [],
#    'location': {'address1': '40500 Paseo Padre Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94538',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['40500 Paseo Padre Pkwy', 'Fremont, CA 94538']},
#    'phone': '+15104944426',
#    'display_phone': '(510) 494-4426',
#    'distance': 5511.1386748793175},
#   {'id': 'wMRfaj7hMDtq_Gx-arlvew',
#    'alias': 'fremont-festival-of-the-arts-fremont-2',
#    'name': 'Fremont Festival of the Arts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/flyiGCJ1xFwqGXPLmt604w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fremont-festival-of-the-arts-fremont-2?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 144,
#    'categories': [{'alias': 'festivals', 'title': 'Festivals'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.55931, 'longitude': -121.95676},
#    'transactions': [],
#    'location': {'address1': '39488 Stevenson Pl',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94536',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['39488 Stevenson Pl', 'Ste 100', 'Fremont, CA 94536']},
#    'phone': '+15107952244',
#    'display_phone': '(510) 795-2244',
#    'distance': 5252.052996363583},
#   {'id': 'SLcUrUz3H-HGHOk0SmEAlQ',
#    'alias': 'lakeshore-park-newark',
#    'name': 'Lakeshore Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o1NEcixE4qgUr_Wqpya6DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lakeshore-park-newark?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 70,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'lakes', 'title': 'Lakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.55353695647182,
#     'longitude': -122.03291587403416},
#    'transactions': [],
#    'location': {'address1': 'Lake Blvd At Parkshore Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '94560',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Lake Blvd At Parkshore Dr', 'Newark, CA 94560']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1942.7884996075961},
#   {'id': '7SE5gY1RM4Jxws2sZlSa0A',
#    'alias': 'niles-canyon-railway-sunol-2',
#    'name': 'Niles Canyon Railway',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_z_Wr9gTrf6qFodhYE79oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/niles-canyon-railway-sunol-2?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 185,
#    'categories': [{'alias': 'museums', 'title': 'Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.59393, 'longitude': -121.88977},
#    'transactions': [],
#    'location': {'address1': '6 Kilkare Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunol',
#     'zip_code': '94586',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6 Kilkare Rd', 'Sunol, CA 94586']},
#    'phone': '+15109968420',
#    'display_phone': '(510) 996-8420',
#    'distance': 11688.151632647492},
#   {'id': 'IpKgMmjsrzFy-5xkLRMUsQ',
#    'alias': 'pacific-bus-museum-fremont',
#    'name': 'Pacific Bus Museum',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uMIdI5ziPEVeGebsORmKDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pacific-bus-museum-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 9,
#    'categories': [{'alias': 'museums', 'title': 'Museums'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.5668296813965,
#     'longitude': -121.984909057617},
#    'transactions': [],
#    'location': {'address1': '37974 Shinn St',
#     'address2': '',
#     'address3': None,
#     'city': 'Fremont',
#     'zip_code': '94536',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['37974 Shinn St', 'Fremont, CA 94536']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2784.411341787737},
#   {'id': 'v2VwnZnRaaAJiTe_vjpaUw',
#    'alias': 'niles-rose-garden-fremont',
#    'name': 'Niles Rose Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5L7p9k-A2t14ZvBhF7jaXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/niles-rose-garden-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 9,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'gardens', 'title': 'Botanical Gardens'},
#     {'alias': 'museums', 'title': 'Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.5792638975944,
#     'longitude': -121.991206414381},
#    'transactions': [],
#    'location': {'address1': '36550 Niles Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Fremont',
#     'zip_code': '94536',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['36550 Niles Blvd', 'Fremont, CA 94536']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2724.2954362654236},
#   {'id': 'KlATxjNy9_QkVHcNE7No8g',
#    'alias': 'gamble-garden-palo-alto-2',
#    'name': 'Gamble Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z5g8U5E0aZ2vCoWKxjF6Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gamble-garden-palo-alto-2?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 166,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'gardens', 'title': 'Botanical Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.440016742651, 'longitude': -122.1482376},
#    'transactions': [],
#    'location': {'address1': '1431 Waverley St',
#     'address2': '',
#     'address3': '',
#     'city': 'Palo Alto',
#     'zip_code': '94301',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1431 Waverley St', 'Palo Alto, CA 94301']},
#    'phone': '+16503291356',
#    'display_phone': '(650) 329-1356',
#    'distance': 18133.86429493319},
#   {'id': 'pVA5WXedU5hA3nwcmkGevA',
#    'alias': 'golden-tee-golfland-castro-valley',
#    'name': 'Golden Tee Golfland',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y6ZrvTWCfeCiwxzZ8atVGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-tee-golfland-castro-valley?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 335,
#    'categories': [{'alias': 'arcades', 'title': 'Arcades'},
#     {'alias': 'mini_golf', 'title': 'Mini Golf'},
#     {'alias': 'eventplanning', 'title': 'Party & Event Planning'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.6925866586699,
#     'longitude': -122.087725876057},
#    'transactions': [],
#    'location': {'address1': '2533 Castro Valley Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Castro Valley',
#     'zip_code': '94546',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2533 Castro Valley Blvd', 'Castro Valley, CA 94546']},
#    'phone': '+15105372168',
#    'display_phone': '(510) 537-2168',
#    'distance': 15483.898113287496},
#   {'id': 'w7m5tjKwpwL_dQBrKvjy5Q',
#    'alias': 'bj-travel-center-fremont',
#    'name': 'BJ Travel Center',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0ciXPJfaM14xAN8Jd30Z2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bj-travel-center-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 53,
#    'categories': [{'alias': 'travelservices', 'title': 'Travel Services'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.533279151263486,
#     'longitude': -121.96192106716448},
#    'transactions': [],
#    'location': {'address1': '3984 Washington Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94538',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3984 Washington Blvd', 'Fremont, CA 94538']},
#    'phone': '+15107968300',
#    'display_phone': '(510) 796-8300',
#    'distance': 5987.024533929745},
#   {'id': 'bpVT34XQfSMFc9gdoLA_og',
#    'alias': 'town-of-niles-fremont',
#    'name': 'Town Of Niles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OIoZfgYG28LA-UrXBZsg2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/town-of-niles-fremont?adjust_creative=spgT8FBiP7sP9-7-q3Wy6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=spgT8FBiP7sP9-7-q3Wy6Q',
#    'review_count': 46,
#    'categories': [{'alias': 'localflavor', 'title': 'Local Flavor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.5768357439748,
#     'longitude': -121.97876775116},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Fremont',
#     'zip_code': '94536',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Fremont, CA 94536']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3571.4179905328037}],
#  'total': 746,
#  'region': {'center': {'longitude': -122.01656341552734,
#    'latitude': 37.56525149649079}}}

# %% [markdown]
# "https://api.yelp.com/v3/businesses/search?location=American%20High%20School%2C%20Fremont&term=attractions&radius=20000&sort_by=best_match&limit=15"
# "https://api.yelp.com/v3/businesses/search?location=American+High+School%2C+Fremont&term=attractions&radius=20000&sort_by=best_match&limit=15"
