# %%
import asyncio
import requests
import json
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# <h3>GraphQL Query Creator</h3>

# %%
import re

def generate_yelp_graphql_queries(search_locations, max_locations_per_query=10):
    """
    Generates a list of GraphQL queries for the Yelp API based on a list of search locations,
    with a maximum of `max_locations_per_query` locations per query.

    Parameters:
    - search_locations (list): A list of dictionaries, each containing 'name', 'address', 'city', 'state', and 'country' keys.
    - max_locations_per_query (int): The maximum number of locations per query.

    Returns:
    - list: A list of GraphQL query strings for the provided search locations.
    """
    # Split search_locations into chunks of max_locations_per_query
    chunks = [search_locations[i:i + max_locations_per_query] for i in range(0, len(search_locations), max_locations_per_query)]
    
    queries = []
    for chunk_index, chunk in enumerate(chunks):
        query_parts = [f"query MyQuery{chunk_index}{{"]
        for index, location in enumerate(chunk):
            # Sanitize the name by removing spaces, special characters, and non-ASCII characters
            sanitized_name = re.sub(r'[^\x20-\x7E\s]', '', location['name'])
            print(sanitized_name)
            sanitized_sanitized_name = re.sub(r'[^a-zA-Z]', '', location['name'])
            # Ensure the address and other strings are properly escaped
            # Construct the business_match query part
            query_parts.append(
                f"{sanitized_sanitized_name}: business_match("
                f"address1: \"{location['address']}\", "
                f"city: \"{location['city']}\", "
                f"country: \"{location['country']}\", "
                f"name: \"{sanitized_name}\", "
                f"state: \"{location['state']}\""
                ") {"
                "  business {"
                "    name"
                "    photos"
                "    rating"
                "    coordinates {"
                "      latitude"
                "      longitude"
                "    }"
                "  }"
                "}"
            )
        query_parts.append("}")
        query = " ".join(query_parts)
        queries.append(query)
    return queries

# %% [markdown]
# <h3>Yelp API Output Parser</h3>

# %%
def parse_yelp_response(response_text):
    """
    Parses the Yelp GraphQL API response and formats it into a list of dictionaries.

    Parameters:
    - response_text (str): The JSON response text from the Yelp API.

    Returns:
    - list: A list of dictionaries, each containing 'name', 'address', 'photo', 'rating', 'lat', and 'lon'.
    """

    formatted_results = []
    print(response_text)

    for search_key, search_result in response_text.items():
        for business in search_result.get('business', []):
            formatted_results.append({
                'name': business.get('name'),
                'photo': business['photos'][0] if business['photos'] else None,
                'rating': business.get('rating'),
                'lat': business['coordinates'].get('latitude'),
                'lon': business['coordinates'].get('longitude')
            })

    return formatted_results

# %% [markdown]
# <h3>Yelp API BATCH Wrapper</h3>

# %% [markdown]
# <h3>Yelp API Location Wrapper</h3>

# %%
async def yelp_wrapper(location, term="attractions", radius=20000, sort_by="best_match", limit=20):
    # Get a list of locations from Yelp API
    params = {
        "location": location,
        "term": term,
        "radius": radius,
        "sort_by": sort_by,
        "limit": limit
    }
    yelp_url = f"https://api.yelp.com/v3/businesses/search?{urllib.parse.urlencode(params)}"
    yelp_header = {
        "accept": "application/json",
        "Authorization": f"Bearer {os.getenv('YELP_API_KEY')}"
    }
    response = await asyncio.to_thread(requests.get, yelp_url, headers=yelp_header)
    if response.status_code == 200:
        yelp_data = response.json()
        # Parse and format the response
        formatted_locations = [
            {
                "name": business.get("name"),
                "address": " ".join(business["location"].get("display_address", [])),
                "photo": business.get("image_url"),
                "rating": business.get("rating"),
                "description": ", ".join(category["title"] for category in business.get("categories", [])),
                "lat": business["coordinates"].get("latitude"),
                "lon": business["coordinates"].get("longitude")
            }
            for business in yelp_data.get("businesses", [])
        ]
        return json.dumps(formatted_locations)
    
    else:
        response.raise_for_status()

# %% [markdown]
# <h3>OpenAI Wrapper</h3>

# %%
from openai import AsyncOpenAI

async def openai_wrapper(location, preferences = ""):
    # Get a list of 10 locations form OpenAI api
    openai_client = AsyncOpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
    print(location, preferences)
    client_content = f"""
I am traveling to {location}, and I want to visit attractions around this area that fit these criteria: {preferences}.
Generate a list of 10 attraction objects and return in this format:
{{
    "attractions": [
        {{
            "name": "<name>",
            "address": "<street address>",
            "city": "<city>",
            "state": "<state>",
            "country": "<country>",
        }}
    ]
}}
"""
    chat_completion = await openai_client.chat.completions.create(
        model="gpt-4-turbo-preview",
        response_format={ "type": "json_object" },
        messages=[
            {"role": "system", "content": "You are a helpful travel assistant designed to output JSON containing a list of objects that have atrribute name and address."},
            {"role": "user", "content": client_content}
        ],
    )
    return json.loads(chat_completion.choices[0].message.content)["attractions"]

# %%
locations = [
    "Fremont, CA",
    "Berkeley, CA",
    "Irvine, CA",
    "New York, NY",
]

preferences = "tech"

openai_tasks = [openai_wrapper(location, preferences) for location in locations]
openai_results = await asyncio.gather(*openai_tasks)
    
print("Openai Results:")
print(openai_results)
    
# Combine the results from all locations
combined_openai_results = [attraction for result in openai_results for attraction in result]
print("Combined OpenAI Results:")
print(len(combined_openai_results))
print(combined_openai_results)
# Out:
# Fremont, CA tech
# Berkeley, CA tech
# Irvine, CA tech
# New York, NY tech
# Openai Results:
# [[{'name': 'Tesla Factory Tour', 'address': '45500 Fremont Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Computer History Museum', 'address': '1401 N Shoreline Blvd', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Intel Museum', 'address': '2200 Mission College Blvd', 'city': 'Santa Clara', 'state': 'CA', 'country': 'USA'}, {'name': 'NASA Ames Research Center', 'address': 'Moffett Field', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Googleplex', 'address': '1600 Amphitheatre Pkwy', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Apple Park Visitor Center', 'address': '10600 N Tantau Ave', 'city': 'Cupertino', 'state': 'CA', 'country': 'USA'}, {'name': 'Facebook HQ', 'address': '1 Hacker Way', 'city': 'Menlo Park', 'state': 'CA', 'country': 'USA'}, {'name': 'The Tech Interactive', 'address': '201 S Market St', 'city': 'San Jose', 'state': 'CA', 'country': 'USA'}, {'name': 'Silicon Valley Innovation Center', 'address': '1850 Gateway Dr', 'city': 'San Mateo', 'state': 'CA', 'country': 'USA'}, {'name': 'Autodesk Gallery', 'address': 'One Market, Floor 2', 'city': 'San Francisco', 'state': 'CA', 'country': 'USA'}], [{'name': 'Lawrence Hall of Science', 'address': '1 Centennial Dr', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Berkeley Marina', 'address': '201 University Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Computer History Museum', 'address': '1401 N Shoreline Blvd', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Exploratorium', 'address': 'Pier 15, The Embarcadero', 'city': 'San Francisco', 'state': 'CA', 'country': 'USA'}, {'name': 'Intel Museum', 'address': '2200 Mission College Blvd', 'city': 'Santa Clara', 'state': 'CA', 'country': 'USA'}, {'name': 'Silicon Valley Innovation Center', 'address': '1850 Gateway Dr Suite #150', 'city': 'San Mateo', 'state': 'CA', 'country': 'USA'}, {'name': 'Tech Interactive', 'address': '201 S Market St', 'city': 'San Jose', 'state': 'CA', 'country': 'USA'}, {'name': 'UC Berkeley College of Engineering', 'address': 'Berkeley Way and Hearst Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Autodesk Gallery', 'address': 'One Market St, Floor 2', 'city': 'San Francisco', 'state': 'CA', 'country': 'USA'}, {'name': 'Googleplex', 'address': '1600 Amphitheatre Parkway', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}], [{'name': 'Irvine Spectrum Center', 'address': '670 Spectrum Center Dr', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Marconi Automotive Museum', 'address': '1302 Industrial Dr', 'city': 'Tustin', 'state': 'CA', 'country': 'USA'}, {'name': 'Orange County Great Park', 'address': '8000 Great Park Blvd', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'The Irvine Museum', 'address': '18881 Von Karman Ave Suite 100', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Google Irvine', 'address': '19510 Jamboree Rd', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Blizzard Entertainment', 'address': '1 Blizzard Way', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'UCI Beall Applied Innovation', 'address': '5270 California Ave Suite 100', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Twitch Irvine', 'address': '350 Spectrum Center Dr Suite 200', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Anduril Industries', 'address': '2722 Michelson Dr', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Amazon Irvine', 'address': '40 Pacifica Suite 900', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}], [{'name': 'The National 9/11 Memorial & Museum', 'address': '180 Greenwich St', 'city': 'New York', 'state': 'NY', 'country': 'USA'}, {'name': 'The Museum of Modern Art (MoMA)', 'address': '11 W 53rd St', 'city': 'New York', 'state': 'NY', 'country': 'USA'}, {'name': 'American Museum of Natural History', ...
# Combined OpenAI Results:
# 40
# [{'name': 'Tesla Factory Tour', 'address': '45500 Fremont Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Computer History Museum', 'address': '1401 N Shoreline Blvd', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Intel Museum', 'address': '2200 Mission College Blvd', 'city': 'Santa Clara', 'state': 'CA', 'country': 'USA'}, {'name': 'NASA Ames Research Center', 'address': 'Moffett Field', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Googleplex', 'address': '1600 Amphitheatre Pkwy', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Apple Park Visitor Center', 'address': '10600 N Tantau Ave', 'city': 'Cupertino', 'state': 'CA', 'country': 'USA'}, {'name': 'Facebook HQ', 'address': '1 Hacker Way', 'city': 'Menlo Park', 'state': 'CA', 'country': 'USA'}, {'name': 'The Tech Interactive', 'address': '201 S Market St', 'city': 'San Jose', 'state': 'CA', 'country': 'USA'}, {'name': 'Silicon Valley Innovation Center', 'address': '1850 Gateway Dr', 'city': 'San Mateo', 'state': 'CA', 'country': 'USA'}, {'name': 'Autodesk Gallery', 'address': 'One Market, Floor 2', 'city': 'San Francisco', 'state': 'CA', 'country': 'USA'}, {'name': 'Lawrence Hall of Science', 'address': '1 Centennial Dr', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Berkeley Marina', 'address': '201 University Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Computer History Museum', 'address': '1401 N Shoreline Blvd', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Exploratorium', 'address': 'Pier 15, The Embarcadero', 'city': 'San Francisco', 'state': 'CA', 'country': 'USA'}, {'name': 'Intel Museum', 'address': '2200 Mission College Blvd', 'city': 'Santa Clara', 'state': 'CA', 'country': 'USA'}, {'name': 'Silicon Valley Innovation Center', 'address': '1850 Gateway Dr Suite #150', 'city': 'San Mateo', 'state': 'CA', 'country': 'USA'}, {'name': 'Tech Interactive', 'address': '201 S Market St', 'city': 'San Jose', 'state': 'CA', 'country': 'USA'}, {'name': 'UC Berkeley College of Engineering', 'address': 'Berkeley Way and Hearst Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Autodesk Gallery', 'address': 'One Market St, Floor 2', 'city': 'San Francisco', 'state': 'CA', 'country': 'USA'}, {'name': 'Googleplex', 'address': '1600 Amphitheatre Parkway', 'city': 'Mountain View', 'state': 'CA', 'country': 'USA'}, {'name': 'Irvine Spectrum Center', 'address': '670 Spectrum Center Dr', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Marconi Automotive Museum', 'address': '1302 Industrial Dr', 'city': 'Tustin', 'state': 'CA', 'country': 'USA'}, {'name': 'Orange County Great Park', 'address': '8000 Great Park Blvd', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'The Irvine Museum', 'address': '18881 Von Karman Ave Suite 100', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Google Irvine', 'address': '19510 Jamboree Rd', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Blizzard Entertainment', 'address': '1 Blizzard Way', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'UCI Beall Applied Innovation', 'address': '5270 California Ave Suite 100', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Twitch Irvine', 'address': '350 Spectrum Center Dr Suite 200', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Anduril Industries', 'address': '2722 Michelson Dr', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'Amazon Irvine', 'address': '40 Pacifica Suite 900', 'city': 'Irvine', 'state': 'CA', 'country': 'USA'}, {'name': 'The National 9/11 Memorial & Museum', 'address': '180 Greenwich St', 'city': 'New York', 'state': 'NY', 'country': 'USA'}, {'name': 'The Museum of Modern Art (MoMA)', 'address': '11 W 53rd St', 'city': 'New York', 'state': 'NY', 'country': 'USA'}, {'name': 'American Museum of Natural History', 'addre ...

# %%
import asyncio
from gql import Client, gql
from gql.transport.aiohttp import AIOHTTPTransport
import os

# Ensure you have the generate_yelp_graphql_queries and parse_yelp_response functions defined as before

async def execute_graphql_query(query_string, headers):
    transport = AIOHTTPTransport(
        url="https://api.yelp.com/v3/graphql",
        headers=headers,
    )
    # Create a GraphQL client using the defined transport
    client = Client(transport=transport, fetch_schema_from_transport=True)
    # Execute the query asynchronously
    query = gql(query_string)
    result = await client.execute_async(query)
    # Close the client after the query is executed
    await client.close_async()
    return result

async def yelp_batch_wrapper(search_locations):
    """
    Fetches data from Yelp API asynchronously using GraphQL.

    Parameters:
    - search_locations (list): A list of dictionaries with 'name' and 'address' for search locations.

    Returns:
    - list: A list of parsed JSON responses from the Yelp API.
    """
    # Generate all GraphQL queries
    graphql_queries = generate_yelp_graphql_queries(search_locations)
    print(graphql_queries)
    
    headers = {
        "Authorization": f"Bearer {os.getenv('YELP_API_KEY')}",
        "Content-Type": "application/json",
    }

    # List to store all the parsed results
    all_parsed_results = []

     # Execute each query sequentially with a one-second delay between them
    for query in graphql_queries:
        result = await execute_graphql_query(query, headers)
        parsed_results = parse_yelp_response(result)
        all_parsed_results.extend(parsed_results)
    
    return all_parsed_results

# Example usage:
# async def main():
#     search_locations = [
#         {"name": "SanJose", "address": "San Jose", "city": "San Jose", "state": "CA", "country": "USA"},
#         {"name": "SanFran", "address": "San Francisco", "city": "San Francisco", "state": "CA", "country": "USA"},
#         # ... more locations ...
#     ]
#     yelp_data = await yelp_batch_wrapper(search_locations)
#     print(yelp_data)

# asyncio.run(main())

# %%
# Feed the combined results into yelp_batch_wrapper
yelp_results = await yelp_batch_wrapper(combined_openai_results)
print("Yelp Results:")
print(yelp_results)
# Out:
# Tesla Factory Tour
# Computer History Museum
# Intel Museum
# NASA Ames Research Center
# Googleplex
# Apple Park Visitor Center
# Facebook HQ
# The Tech Interactive
# Silicon Valley Innovation Center
# Autodesk Gallery
# Lawrence Hall of Science
# Berkeley Marina
# Computer History Museum
# Exploratorium
# Intel Museum
# Silicon Valley Innovation Center
# Tech Interactive
# UC Berkeley College of Engineering
# Autodesk Gallery
# Googleplex
# Irvine Spectrum Center
# Marconi Automotive Museum
# Orange County Great Park
# The Irvine Museum
# Google Irvine
# Blizzard Entertainment
# UCI Beall Applied Innovation
# Twitch Irvine
# Anduril Industries
# Amazon Irvine
# The National 911 Memorial  Museum
# The Museum of Modern Art MoMA
# American Museum of Natural History
# One World Observatory
# Empire State Building
# The High Line
# Statue of Liberty National Monument
# Brooklyn Bridge
# Central Park
# Times Square
# ['query MyQuery0{ TeslaFactoryTour: business_match(address1: "", city: "Fremont", country: "USA", name: "Tesla Factory Tour", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} ComputerHistoryMuseum: business_match(address1: "", city: "Mountain View", country: "USA", name: "Computer History Museum", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} IntelMuseum: business_match(address1: "", city: "Santa Clara", country: "USA", name: "Intel Museum", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} NASAAmesResearchCenter: business_match(address1: "", city: "Mountain View", country: "USA", name: "NASA Ames Research Center", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} Googleplex: business_match(address1: "", city: "Mountain View", country: "USA", name: "Googleplex", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} AppleParkVisitorCenter: business_match(address1: "", city: "Cupertino", country: "USA", name: "Apple Park Visitor Center", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} FacebookHQ: business_match(address1: "", city: "Menlo Park", country: "USA", name: "Facebook HQ", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} TheTechInteractive: business_match(address1: "", city: "San Jose", country: "USA", name: "The Tech Interactive", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} SiliconValleyInnovationCenter: business_match(address1: "", city: "San Mateo", country: "USA", name: "Silicon Valley Innovation Center", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} AutodeskGallery: business_match(address1: "", city: "San Francisco", country: "USA", name: "Autodesk Gallery", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} }', 'query MyQuery1{ LawrenceHallofScience: business_match(address1: "", city: "Berkeley", country: "USA", name: "Lawrence Hall of Science", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} BerkeleyMarina: business_match(address1: "", city: "Berkeley", country: "USA", name: "Berkeley Marina", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} ComputerHistoryMuseum: business_match(address1: "", city: "Mountain View", country: "USA", name: "Computer History Museum", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} Exploratorium: business_match(address1: "", city: "San Francisco", country: "USA", name: "Exploratorium", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} IntelMuseum: business_match(address1: "", city: "Santa Clara", country: "USA", name: "Intel Museum", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} SiliconValleyInnovationCenter: business_match(address1: "", city: "San Mateo", country: "USA", name: "Silicon Valley Innovation Center", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} TechInteractive: business_match(address1: "", city: "San Jose", country: "USA", name: "Tech Interactive", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} UCBerkeleyCollegeofEngineering: business_match(address1: "", city: "Berkeley", country: "USA", name: "UC Berkeley College of Engineering", state: "CA") ...
# {'TeslaFactoryTour': {'business': []}, 'ComputerHistoryMuseum': {'business': []}, 'IntelMuseum': {'business': [{'name': 'Intel Museum', 'photos': ['https://s3-media2.fl.yelpcdn.com/bphoto/gM8u6Cd439eBi6ncchSsVw/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude':
 'photo': 'https://s3-media2.fl.yelpcdn.com/bphoto/8dWtYbMkHKNgyKe5S1DZkA/o.jpg', 'rating': 4.5, 'lat': 40.7396039, 'lon': -74.00847657515718}, {'name': 'Times Square', 'photo': 'https://s3-media3.fl.yelpcdn.com/bphoto/PX3aQh1-g1XG0mzIo-jv6Q/o.jpg', 'rating': 4.0, 'lat': 40.75643250013289, 'lon': -73.98644725547547}]

# %% [markdown]
# <h3>Attractions Wrapper</h3>

# %%
async def attractions_wrapper(location, preferences=""):
    # Get results from OpenAI
    openai_result = await openai_wrapper(location, preferences)
        
    # Feed addresses from openai_result back into yelp_wrapper
    yelp_results = await yelp_batch_wrapper(openai_result)
    print(yelp_results)

# %%
# async def attractions_wrapper(locations, preferences=""):
#     # Get results from OpenAI
#     for location in locations:
#         openai_result = await openai_wrapper(location, preferences)
        
#     # Feed addresses from openai_result back into yelp_wrapper
#     yelp_results = await yelp_batch_wrapper(openai_result)
    
#     print(yelp_results)

async def attractions_wrapper(locations, preferences=""):
    # Run openai_wrapper concurrently for all locations
    openai_tasks = [openai_wrapper(location, preferences) for location in locations]
    openai_results = await asyncio.gather(*openai_tasks)
    
    print("Openai Results:")
    print(openai_results)
    
    # Combine the results from all locations
    combined_openai_results = [attraction for result in openai_results for attraction in result]
    print("Combined OpenAI Results:")
    print(len(combined_openai_results))
    print(combined_openai_results)
    
    # Feed the combined results into yelp_batch_wrapper
    yelp_results = await yelp_batch_wrapper(combined_openai_results)
    print("Yelp Results:")
    print(yelp_results)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# await attractions_wrapper(["San Francisco, CA"], "museums")
cities = [
    "Fremont, CA",
    "Berkeley, CA",
    "Irvine, CA",
    "New York, NY",
    "Washington, DC",
    "Chicago, IL",
]

await attractions_wrapper(cities, "boba tea")
# Out:
# Fremont, CA boba tea
# Berkeley, CA boba tea
# Irvine, CA boba tea
# New York, NY boba tea
# Washington, DC boba tea
# Chicago, IL boba tea
# Openai Results:
# [[{'name': 'T4', 'address': '43421 Christy St', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Happy Lemon', 'address': '46827 Warm Springs Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Gong Cha', 'address': '39230 Argonaut Way', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Tea Island', 'address': '46132 Warm Springs Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Sharetea', 'address': '3944 Washington Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'One Tea', 'address': '46873 Warm Springs Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Super Cue Cafe', 'address': '43773 Boscell Rd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Teaspoon', 'address': '41093 Fremont Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Feng Cha Teahouse', 'address': '39030 Paseo Padre Pkwy', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}, {'name': 'Yi Fang Taiwan Fruit Tea', 'address': '34420 Fremont Blvd', 'city': 'Fremont', 'state': 'CA', 'country': 'USA'}], [{'name': 'Ashà Tea House', 'address': '2086 University Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'U-Cha', 'address': '2199 Bancroft Way', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'RareTea', 'address': '2284 Shattuck Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Feng Cha Teahouse', 'address': '2521 Durant Ave E', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Happy Lemon', 'address': '1941 University Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'TeaOne', 'address': '2516 Durant Ave Ste B', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Asha Tea House', 'address': '2086 University Ave', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Sharetea', 'address': '2440 Bancroft Way Ste 102', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'YiFang Taiwan Fruit Tea', 'address': '2516 Bancroft Way', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'}, {'name': 'Purple Kow', 'address': '2164 Center St', 'city': 'Berkeley', 'state': 'CA', 'country': 'USA'
 'city': 'New York', 'state': 'NY', 'country': 'USA'}, {'name': "Ten Ren's Tea Time", 'address': '79 Mott St', 'city': 'New York', 'state': 'NY', 'country': 'USA'}, {'name': 'Tiger Sugar', 'address': '197 Canal St', 'city': 'New York', 'state': 'NY', 'country': ' ...
# T4
# Happy Lemon
# Gong Cha
# Tea Island
# Sharetea
# One Tea
# Super Cue Cafe
# Teaspoon
# Feng Cha Teahouse
# Yi Fang Taiwan Fruit Tea
# Ash Tea House
# U-Cha
# RareTea
# Feng Cha Teahouse
# Happy Lemon
# TeaOne
# Asha Tea House
# Sharetea
# YiFang Taiwan Fruit Tea
# Purple Kow
# Sharetea
# 7 Leaves Cafe
# Omomo Tea Shoppe
# Tiger Sugar
# TP Tea
# Sunright Tea Studio
# The Alley
# Honey & Lavender Espresso Bar
# Cha For Tea
# Gong Cha
# Vivi Bubble Tea
# Gong Cha
# Bobba Guys
# Kung Fu Tea
# Ten Ren's Tea Time
# Tiger Sugar
# Happy Lemon
# CoCo Fresh Tea & Juice
# Yi Fang Taiwan Fruit Tea
# The Alley
# Kung Fu Tea
# Gong Cha
# Ten Ren's Tea Time
# Chatime
# Panda Bubble Tea
# Bubble Tea Licious
# CoCo Fresh Tea & Juice
# Tigersugar
# Boba Guys
# Sharetea
# Kung Fu Tea
# Chatime
# Tsaocaa
# Coco Fresh Tea & Juice
# Bingo Tea
# Tea Ninja
# Happy Lemon
# Zero Degrees
# Joy Yee
# Te'amo Boba Bar
# ['query MyQuery0{ T: business_match(address1: "43421 Christy St", city: "Fremont", country: "USA", name: "T4", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} HappyLemon: business_match(address1: "46827 Warm Springs Blvd", city: "Fremont", country: "USA", name: "Happy Lemon", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} GongCha: business_match(address1: "39230 Argonaut Way", city: "Fremont", country: "USA", name: "Gong Cha", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} TeaIsland: business_match(address1: "46132 Warm Springs Blvd", city: "Fremont", country: "USA", name: "Tea Island", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} Sharetea: business_match(address1: "3944 Washington Blvd", city: "Fremont", country: "USA", name: "Sharetea", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} OneTea: business_match(address1: "46873 Warm Springs Blvd", city: "Fremont", country: "USA", name: "One Tea", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} SuperCueCafe: business_match(address1: "43773 Boscell Rd", city: "Fremont", country: "USA", name: "Super Cue Cafe", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} Teaspoon: business_match(address1: "41093 Fremont Blvd", city: "Fremont", country: "USA", name: "Teaspoon", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} FengChaTeahouse: business_match(address1: "39030 Paseo Padre Pkwy", city: "Fremont", country: "USA", name: "Feng Cha Teahouse", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} YiFangTaiwanFruitTea: business_match(address1: "34420 Fremont Blvd", city: "Fremont", country: "USA", name: "Yi Fang Taiwan Fruit Tea", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} }', 'query MyQuery1{ AshTeaHouse: business_match(address1: "2086 University Ave", city: "Berkeley", country: "USA", name: "Ash Tea House", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} UCha: business_match(address1: "2199 Bancroft Way", city: "Berkeley", country: "USA", name: "U-Cha", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} RareTea: business_match(address1: "2284 Shattuck Ave", city: "Berkeley", country: "USA", name: "RareTea", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} FengChaTeahouse: business_match(address1: "2521 Durant Ave E", city: "Berkeley", country: "USA", name: "Feng Cha Teahouse", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} HappyLemon: business_match(address1: "1941 University Ave", city: "Berkeley", country: "USA", name: "Happy Lemon", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} TeaOne: business_match(address1: "2516 Durant Ave Ste B", city: "Berkeley", country: "USA", name: "TeaOne", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} AshaTeaHouse: business_match(address1: "2086 University Ave", city: "Berkeley", country: "USA", name: "Asha Tea House", state: "CA") {  business {    name    photos    rating    coordinates {      latitude      longitude    }  }} Sharetea: business_match(address1: "2440 Bancroft Way Ste 102", city: "Berkeley", country: "USA", name: "Sharetea", state: "CA") {  business {    name    pho ...
# {'T': {'business': []}, 'HappyLemon': {'business': [{'name': 'Happy Lemon', 'photos': ['https://s3-media2.fl.yelpcdn.com/bphoto/pUKbN0wSCchGz9IrKuuyww/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 37.488188, 'longitude': -121.930199}}]}, 'GongCha': {'business': []}, 'TeaIsland': {'business': [{'name': 'Tea Island', 'photos': ['https://s3-media4.fl.yelpcdn.com/bphoto/CKGH4Vkh80h4NxIB_49zqQ/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 37.4935414360443, 'longitude': -121.929889351584}}]}, 'Sharetea': {'business': [{'name': 'Sharetea', 'photos': ['https://s3-media2.fl.yelpcdn.com/bphoto/L2siVLKAgmXmU4GG6nkrkw/o.jpg'], 'rating': 3.5, 'coordinates': {'latitude': 37.53195, 'longitude': -121.95789}}]}, 'OneTea': {'business': [{'name': 'One Tea', 'photos': ['https://s3-media3.fl.yelpcdn.com/bphoto/rXVp6owiH62rdRWuobjxIQ/o.jpg'], 'rating': 4.5, 'coordinates': {'latitude': 37.4890666928572, 'longitude': -121.929413750767}}]}, 'SuperCueCafe': {'business': [{'name': 'Super Cue Cafe', 'photos': ['https://s3-media2.fl.yelpcdn.com/bphoto/tp7CTE89LQ9t2eSH88-u2Q/o.jpg'], 'rating': 3.5, 'coordinates': {'latitude': 37.50028, 'longitude': -121.973891}}]}, 'Teaspoon': {'business': []}, 'FengChaTeahouse': {'business': []}, 'YiFangTaiwanFruitTea': {'business': []}}
# {'AshTeaHouse': {'business': [{'name': 'Asha Tea House', 'photos': ['https://s3-media2.fl.yelpcdn.com/bphoto/zFRuLuPRnvmZ3xMtd3oaqA/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 37.8719582, 'longitude': -122.268859}}]}, 'UCha': {'business': [{'name': 'U Cha', 'photos': ['https://s3-media3.fl.yelpcdn.com/bphoto/lFXz_HcNRxvelImd4iJxlw/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 37.8718211, 'longitude': -122.2601405}}]}, 'RareTea': {'business': []}, 'FengChaTeahouse': {'business': [{'name': 'Feng Cha Teahouse  奉茶', 'photos': ['https://s3-media1.fl.yelpcdn.com/bphoto/LvULrM_rbSnWxCmx2ZQ6tA/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 37.867704, 'longitude': -122.257685}}]}, 'HappyLemon': {'business': []}, 'TeaOne': {'business': []}, 'AshaTeaHouse': {'business': [{'name': 'Asha Tea House', 'photos': ['https://s3-media2.fl.yelpcdn.com/bphoto/zFRuLuPRnvmZ3xMtd3oaqA/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 37.8719582, 'longitude': -122.268859}}]}, 'Sharetea': {'business': []}, 'YiFangTaiwanFruitTea': {'business': [{'name': 'Yi Fang Taiwan Fruit Tea', 'photos': ['https://s3-media4.fl.yelpcdn.com/bphoto/tdggcMGDuV99dhnX2KOHyw/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 37.86868712916702, 'longitude': -122.258649}}]}, 'PurpleKow': {'business': []}}
# {'Sharetea': {'business': []}, 'LeavesCafe': {'business': [{'name': '7 Leaves Cafe', 'photos': ['https://s3-media3.fl.yelpcdn.com/bphoto/TE_aE3MCjgZiRCDFwNi6gg/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude': 33.687569118670716, 'longitude': -117.77133402002308}}]}, 'OmomoTeaShoppe': {'business': [{'name': 'OMOMO Tea Shoppe', 'photos': ['https://s3-media4.fl.yelpcdn.com/bphoto/WBS2vox0zkpY15eDy3nOOQ/o.jpg'], 'rating': 4.0, 'coordinates': {'latitude':